# %% [markdown]
# # requests

# %% [markdown]
# ## 响应内容

# %%
import requests

# %% [markdown]
# r.status_code #响应状态码
# r.raw #返回原始响应体，也就是 urllib 的 response 对象，使用 r.raw.read() 读取
# r.content #字节(bytes)方式的响应体，会自动为你解码 gzip 和 deflate 压缩
# r.text #字符串(str)方式的响应体，会自动根据响应头部的字符编码进行解码
# r.headers #以字典对象存储服务器响应头，但是这个字典比较特殊，字典键不区分大小写，若键不存在则返回None
# #*特殊方法*#
# r.json() #Requests中内置的JSON解码器
# r.raise_for_status() #失败请求(非200响应)抛出异常

# %%
r = requests.get('https://api.github.com/events')

# %% [markdown]
# ## status_code

# %%
#响应状态码  
r.status_code
# Out:
# 200

# %% [markdown]
# ## headers

# %% [markdown]
# 以字典对象存储服务器响应头，但是这个字典比较特殊，字典键不区分大小写，若键不存在则返回None

# %%
r.headers
# Out:
# {'X-Content-Type-Options': 'nosniff', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Encoding': 'gzip', 'Vary': 'Accept, Accept-Encoding', 'Link': '<https://api.github.com/events?page=2>; rel="next", <https://api.github.com/events?page=10>; rel="last"', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'X-Poll-Interval': '60', 'Last-Modified': 'Fri, 25 Jan 2019 00:38:10 GMT', 'X-GitHub-Request-Id': '5563:7B23:228F5B:2EF783:5C4A5B9D', 'Status': '200 OK', 'Content-Type': 'application/json; charset=utf-8', 'Content-Security-Policy': "default-src 'none'", 'X-XSS-Protection': '1; mode=block', 'X-RateLimit-Remaining': '54', 'Server': 'GitHub.com', 'X-Frame-Options': 'deny', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'Transfer-Encoding': 'chunked', 'Date': 'Fri, 25 Jan 2019 00:43:10 GMT', 'X-GitHub-Media-Type': 'github.v3; format=json', 'X-RateLimit-Limit': '60', 'Access-Control-Expose-Headers': 'ETag, Link, Location, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval, X-GitHub-Media-Type', 'X-RateLimit-Reset': '1548378696', 'ETag': 'W/"4b9b5f41b5aecc74fabb62c9693e1e50"'}

# %%
print(type(r.headers))
# Out:
# <class 'requests.structures.CaseInsensitiveDict'>

# %% [markdown]
# ## text

# %% [markdown]
# 字符串(str)方式的响应体，会自动根据响应头部的字符编码进行解码

# %%
r.text
# Out:
# '[{"id":"8948064197","type":"PushEvent","actor":{"id":22704262,"login":"alexmihaes","display_login":"alexmihaes","gravatar_id":"","url":"https://api.github.com/users/alexmihaes","avatar_url":"https://avatars.githubusercontent.com/u/22704262?"},"repo":{"id":152572042,"name":"alexmihaes/cool-calendar","url":"https://api.github.com/repos/alexmihaes/cool-calendar"},"payload":{"push_id":3242231016,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"eadec5352608a2db67757e2fdd8befd6222d536a","before":"d38ba3da2a5acdb0fb7611e2dae40da280d90a05","commits":[{"sha":"eadec5352608a2db67757e2fdd8befd6222d536a","author":{"email":"alexmihaes@users.noreply.github.com","name":"Alex Mihăeș"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/alexmihaes/cool-calendar/commits/eadec5352608a2db67757e2fdd8befd6222d536a"}]},"public":true,"created_at":"2019-01-25T00:38:10Z"},{"id":"8948064192","type":"PushEvent","actor":{"id":467739,"login":"larham","display_login":"larham","gravatar_id":"","url":"https://api.github.com/users/larham","avatar_url":"https://avatars.githubusercontent.com/u/467739?"},"repo":{"id":91118401,"name":"greenplum-db/gpbackup","url":"https://api.github.com/repos/greenplum-db/gpbackup"},"payload":{"push_id":3242231015,"size":2,"distinct_size":2,"ref":"refs/heads/stringarray_flags","head":"d52a00237e284d61eb8d429b40e1157e9123dc09","before":"a8def986cfb6db0da202d0522b227883d88f8ab7","commits":[{"sha":"66cd916072f395324895726195360584c7cfe93f","author":{"email":"kyeap@pivotal.io","name":"Kevin Yeap"},"message":"Add integration test for RetrieveAndProcessTables\\n\\n* move initialization of global \\"objectCounts\\" to the DoInit() method\\nfor ease of testing\\n\\nCo-authored-by: Kevin Yeap <kyeap@pivotal.io>\\nCo-authored-by: Larry Hamel <lhamel@pivotal.io>","distinct":true,"url":"https://api.github.com/repos/greenplum-db/gpbackup/commits/66cd916072f395324895726195360584c7cfe93f"},{"sha":"d52a00237e284d61eb8d429b40e1157e9123dc09","author":{"email":"lhamel@pivotal.io","name":"Larry Hamel"},"message":"WIP: Needs CLEANUP  successful end to end test with special char.\\n\\nCo-authored-by: Kevin Yeap <kyeap@pivotal.io>\\nCo-authored-by: Larry Hamel <lhamel@pivotal.io>","distinct":true,"url":"https://api.github.com/repos/greenplum-db/gpbackup/commits/d52a00237e284d61eb8d429b40e1157e9123dc09"}]},"public":true,"created_at":"2019-01-25T00:38:10Z","org":{"id":14097842,"login":"greenplum-db","gravatar_id":"","url":"https://api.github.com/orgs/greenplum-db","avatar_url":"https://avatars.githubusercontent.com/u/14097842?"}},{"id":"8948064191","type":"PushEvent","actor":{"id":27036313,"login":"tpjohnson","display_login":"tpjohnson","gravatar_id":"","url":"https://api.github.com/users/tpjohnson","avatar_url":"https://avatars.githubusercontent.com/u/27036313?"},"repo":{"id":167255890,"name":"tpjohnson/tpjohnson.github.io","url":"https://api.github.com/repos/tpjohnson/tpjohnson.github.io"},"payload":{"push_id":3242231013,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1fad96341b53048667ba0d4fb773d9e124559660","before":"fe791e428f424cddffd022a5ab8b270136e3ea1a","commits":[{"sha":"1fad96341b53048667ba0d4fb773d9e124559660","author":{"email":"trevorjohnson.tj@gmail.com","name":"Trevor"},"message":"new theme","distinct":true,"url":"https://api.github.com/repos/tpjohnson/tpjohnson.github.io/commits/1fad96341b53048667ba0d4fb773d9e124559660"}]},"public":true,"created_at":"2019-01-25T00:38:10Z"},{"id":"8948064190","type":"PushEvent","actor":{"id":5234749,"login":"rthaut","display_login":"rthaut","gravatar_id":"","url":"https://api.github.com/users/rthaut","avatar_url":"https://avatars.githubusercontent.com/u/5234749?"},"repo":{"id":55986170,"name":"rthaut/YouTubePopoutPlayer","url":"https://api.github.com/repos/rthaut/YouTubePopoutPlayer"},"payload":{"push_id":3242231012,"size":4,"distinct_size":1,"ref":"refs/heads/release/3.0","head":"91a12120ae32f414b637ff353b80f7bd3b40529c","before":"8681404477a9bfef778d7d ...

# %%
#反回字符串
type(r.text)
# Out:
# str

# %% [markdown]
# ## content

# %%
# 字节(bytes)方式的响应体，会自动为你解码 gzip 和 deflate 压缩  
r.content
# r.json()
# Out:
# b'[{"id":"8948064197","type":"PushEvent","actor":{"id":22704262,"login":"alexmihaes","display_login":"alexmihaes","gravatar_id":"","url":"https://api.github.com/users/alexmihaes","avatar_url":"https://avatars.githubusercontent.com/u/22704262?"},"repo":{"id":152572042,"name":"alexmihaes/cool-calendar","url":"https://api.github.com/repos/alexmihaes/cool-calendar"},"payload":{"push_id":3242231016,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"eadec5352608a2db67757e2fdd8befd6222d536a","before":"d38ba3da2a5acdb0fb7611e2dae40da280d90a05","commits":[{"sha":"eadec5352608a2db67757e2fdd8befd6222d536a","author":{"email":"alexmihaes@users.noreply.github.com","name":"Alex Mih\xc4\x83e\xc8\x99"},"message":"Update README.md","distinct":true,"url":"https://api.github.com/repos/alexmihaes/cool-calendar/commits/eadec5352608a2db67757e2fdd8befd6222d536a"}]},"public":true,"created_at":"2019-01-25T00:38:10Z"},{"id":"8948064192","type":"PushEvent","actor":{"id":467739,"login":"larham","display_login":"larham","gravatar_id":"","url":"https://api.github.com/users/larham","avatar_url":"https://avatars.githubusercontent.com/u/467739?"},"repo":{"id":91118401,"name":"greenplum-db/gpbackup","url":"https://api.github.com/repos/greenplum-db/gpbackup"},"payload":{"push_id":3242231015,"size":2,"distinct_size":2,"ref":"refs/heads/stringarray_flags","head":"d52a00237e284d61eb8d429b40e1157e9123dc09","before":"a8def986cfb6db0da202d0522b227883d88f8ab7","commits":[{"sha":"66cd916072f395324895726195360584c7cfe93f","author":{"email":"kyeap@pivotal.io","name":"Kevin Yeap"},"message":"Add integration test for RetrieveAndProcessTables\\n\\n* move initialization of global \\"objectCounts\\" to the DoInit() method\\nfor ease of testing\\n\\nCo-authored-by: Kevin Yeap <kyeap@pivotal.io>\\nCo-authored-by: Larry Hamel <lhamel@pivotal.io>","distinct":true,"url":"https://api.github.com/repos/greenplum-db/gpbackup/commits/66cd916072f395324895726195360584c7cfe93f"},{"sha":"d52a00237e284d61eb8d429b40e1157e9123dc09","author":{"email":"lhamel@pivotal.io","name":"Larry Hamel"},"message":"WIP: Needs CLEANUP  successful end to end test with special char.\\n\\nCo-authored-by: Kevin Yeap <kyeap@pivotal.io>\\nCo-authored-by: Larry Hamel <lhamel@pivotal.io>","distinct":true,"url":"https://api.github.com/repos/greenplum-db/gpbackup/commits/d52a00237e284d61eb8d429b40e1157e9123dc09"}]},"public":true,"created_at":"2019-01-25T00:38:10Z","org":{"id":14097842,"login":"greenplum-db","gravatar_id":"","url":"https://api.github.com/orgs/greenplum-db","avatar_url":"https://avatars.githubusercontent.com/u/14097842?"}},{"id":"8948064191","type":"PushEvent","actor":{"id":27036313,"login":"tpjohnson","display_login":"tpjohnson","gravatar_id":"","url":"https://api.github.com/users/tpjohnson","avatar_url":"https://avatars.githubusercontent.com/u/27036313?"},"repo":{"id":167255890,"name":"tpjohnson/tpjohnson.github.io","url":"https://api.github.com/repos/tpjohnson/tpjohnson.github.io"},"payload":{"push_id":3242231013,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"1fad96341b53048667ba0d4fb773d9e124559660","before":"fe791e428f424cddffd022a5ab8b270136e3ea1a","commits":[{"sha":"1fad96341b53048667ba0d4fb773d9e124559660","author":{"email":"trevorjohnson.tj@gmail.com","name":"Trevor"},"message":"new theme","distinct":true,"url":"https://api.github.com/repos/tpjohnson/tpjohnson.github.io/commits/1fad96341b53048667ba0d4fb773d9e124559660"}]},"public":true,"created_at":"2019-01-25T00:38:10Z"},{"id":"8948064190","type":"PushEvent","actor":{"id":5234749,"login":"rthaut","display_login":"rthaut","gravatar_id":"","url":"https://api.github.com/users/rthaut","avatar_url":"https://avatars.githubusercontent.com/u/5234749?"},"repo":{"id":55986170,"name":"rthaut/YouTubePopoutPlayer","url":"https://api.github.com/repos/rthaut/YouTubePopoutPlayer"},"payload":{"push_id":3242231012,"size":4,"distinct_size":1,"ref":"refs/heads/release/3.0","head":"91a12120ae32f414b637ff353b80f7bd3b40529c","before":"8681404 ...

# %% [markdown]
# ## JSON 响应内容

# %% [markdown]
# 如果 JSON 解码失败， r.json() 就会抛出一个异常。例如，响应内容是 401 (Unauthorized)，尝试访问 r.json() 将会抛出 ValueError: No JSON object could be decoded 异常。
#
# 需要注意的是，成功调用 r.json() 并**不**意味着响应的成功。有的服务器会在失败的响应中包含一个 JSON 对象（比如 HTTP 500 的错误细节）。这种 JSON 会被解码返回。要检查请求是否成功，请使用 r.raise_for_status() 或者检查 r.status_code 是否和你的期望相同。

# %%
def get_json():
    r = requests.get('https://api.github.com/events')
    print(r.status_code)
    print(r.headers['Content-Type'])
    print(r.json())

# %%
get_json()
# Out:
# 200
# application/json; charset=utf-8
# [{'payload': {'master_branch': 'master', 'description': 'WebPack', 'ref_type': 'branch', 'ref': 'master', 'pusher_type': 'user'}, 'id': '8947950361', 'public': True, 'actor': {'gravatar_id': '', 'id': 7291350, 'login': 'montrubio', 'url': 'https://api.github.com/users/montrubio', 'avatar_url': 'https://avatars.githubusercontent.com/u/7291350?', 'display_login': 'montrubio'}, 'type': 'CreateEvent', 'repo': {'url': 'https://api.github.com/repos/montrubio/PENTWI15', 'name': 'montrubio/PENTWI15', 'id': 167456945}, 'created_at': '2019-01-25T00:06:36Z'}, {'payload': {'commits': [], 'push_id': 3242169603, 'head': 'd04da1ab08e39d85049b25c725e22c6583d406c4', 'before': 'd04da1ab08e39d85049b25c725e22c6583d406c4', 'distinct_size': 0, 'size': 0, 'ref': 'refs/heads/issue/NEST-248'}, 'org': {'url': 'https://api.github.com/orgs/Lombiq', 'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?', 'gravatar_id': '', 'id': 8158177, 'login': 'Lombiq'}, 'id': '8947950351', 'public': True, 'actor': {'gravatar_id': '', 'id': 8517910, 'login': 'LombiqBot', 'url': 'https://api.github.com/users/LombiqBot', 'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?', 'display_login': 'LombiqBot'}, 'type': 'PushEvent', 'repo': {'url': 'https://api.github.com/repos/Lombiq/Smart-Notifications', 'name': 'Lombiq/Smart-Notifications', 'id': 43380114}, 'created_at': '2019-01-25T00:06:35Z'}, {'payload': {}, 'id': '8947950352', 'public': True, 'actor': {'gravatar_id': '', 'id': 18314036, 'login': 'JannikLassahn', 'url': 'https://api.github.com/users/JannikLassahn', 'avatar_url': 'https://avatars.githubusercontent.com/u/18314036?', 'display_login': 'JannikLassahn'}, 'type': 'PublicEvent', 'repo': {'url': 'https://api.github.com/repos/JannikLassahn/wpf-dg-test', 'name': 'JannikLassahn/wpf-dg-test', 'id': 167456562}, 'created_at': '2019-01-25T00:06:35Z'}, {'payload': {'action': 'opened', 'number': 16350, 'pull_request': {'user': {'starred_url': 'https://api.github.com/users/bwasti/starred{/owner}{/repo}', 'gravatar_id': '', 'gists_url': 'https://api.github.com/users/bwasti/gists{/gist_id}', 'html_url': 'https://github.com/bwasti', 'node_id': 'MDQ6VXNlcjQ4NDI5MDg=', 'repos_url': 'https://api.github.com/users/bwasti/repos', 'following_url': 'https://api.github.com/users/bwasti/following{/other_user}', 'site_admin': False, 'subscriptions_url': 'https://api.github.com/users/bwasti/subscriptions', 'followers_url': 'https://api.github.com/users/bwasti/followers', 'events_url': 'https://api.github.com/users/bwasti/events{/privacy}', 'id': 4842908, 'login': 'bwasti', 'received_events_url': 'https://api.github.com/users/bwasti/received_events', 'url': 'https://api.github.com/users/bwasti', 'avatar_url': 'https://avatars2.githubusercontent.com/u/4842908?v=4', 'type': 'User', 'organizations_url': 'https://api.github.com/users/bwasti/orgs'}, 'mergeable_state': 'unknown', 'issue_url': 'https://api.github.com/repos/pytorch/pytorch/issues/16350', 'labels': [], '_links': {'statuses': {'href': 'https://api.github.com/repos/pytorch/pytorch/statuses/477279337d942d372f96d67755b20e2fea346cd1'}, 'review_comment': {'href': 'https://api.github.com/repos/pytorch/pytorch/pulls/comments{/number}'}, 'html': {'href': 'https://github.com/pytorch/pytorch/pull/16350'}, 'review_comments': {'href': 'https://api.github.com/repos/pytorch/pytorch/pulls/16350/comments'}, 'commits': {'href': 'https://api.github.com/repos/pytorch/pytorch/pulls/16350/commits'}, 'self': {'href': 'https://api.github.com/repos/pytorch/pytorch/pulls/16350'}, 'issue': {'href': 'https://api.github.com/repos/pytorch/pytorch/issues/16350'}, 'comments': {'href': 'https://api.github.com/repos/pytorch/pytorch/issues/16350/comments'}}, 'milestone': None, 'created_at': '2019-01-25T00:06:35Z', 'rebaseable': None, 'html_url': 'https://github.com/pytorch/pytorch/pull/16350', 'statuses_url': 'https://api.github.com/repos/pytorch/pytorch/statuses/477279337d942d372f96d67755b20e2fea346cd1', 'commits': 4, 'changed_files': 9, 'head' ...

# %% [markdown]
# ## 传递 URL 参数

# %%
def get_querystring():
    params = {'qs1': 'value1', 'qs2': 'value2'}
    r = requests.get('http://httpbin.org/get', params=params)
    print(r.status_code)
    print(r.content)
#     print(r.json())

# %%
get_querystring()
# Out:
# 200
# b'{\n  "args": {\n    "qs1": "value1", \n    "qs2": "value2"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.11.1"\n  }, \n  "origin": "58.248.180.249", \n  "url": "http://httpbin.org/get?qs2=value2&qs1=value1"\n}\n'

# %% [markdown]
# ## 定制请求头

# %%
def get_custom_headers():
    headers = {'x-header1': 'value1', 'x-header2': 'value2'}
    r = requests.get('http://httpbin.org/get', headers=headers)
    print(r.status_code)
    print(r.content)

# %%
get_custom_headers()
# Out:
# 200
# b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.11.1", \n    "X-Header1": "value1", \n    "X-Header2": "value2"\n  }, \n  "origin": "58.248.180.249", \n  "url": "http://httpbin.org/get"\n}\n'

# %%
def get_cookie():
    headers = {'User-Agent': 'Chrome'}
    url = 'http://www.douban.com'
    r = requests.get(url, headers=headers)
    print(r.status_code)
    print(r.cookies)
    requests.get(url, headers=headers)
    print(r.status_code)
    print(r.cookies)

# %%
get_cookie()
# Out:
# 200
# <RequestsCookieJar[<Cookie bid=OCspeeeNChw for .douban.com/>, <Cookie ll="118281" for .douban.com/>]>
# 200
# <RequestsCookieJar[<Cookie bid=OCspeeeNChw for .douban.com/>, <Cookie ll="118281" for .douban.com/>]>
